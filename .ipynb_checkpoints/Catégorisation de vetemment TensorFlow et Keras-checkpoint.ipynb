# %% [markdown]
# Etape 1 : Set up un environnement virtuel et installation de tensorflow, dans le terminal les commandes sont :

# %% [raw]
# pip install virtualenv

# %% [raw]
# virtualenv myenv

# %% [raw]
# myenv\Scripts\activate.bat

# %% [raw]
# pip install tensorflow

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.16.1

# %% [markdown]
# Etape 2 : On importe les données de Keras. Chaque catégorie est remplacer par un nombre donc il faudra une table de conversion (class_name)

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist #Importation de la database Fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data() #Chargement de la database
train_images = train_images/255 #Normalisation des pixels 
test_images = test_images/255 #Idem

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'] #Conversion des train_labels en catégorie lisible


print ('Nombre d image de la database : ', train_images.shape[0])
print('Taille de toutes les images de la database : ', train_images.shape[1:3])
# Out:
# Nombre d image de la database :  60000
# Taille de toutes les images de la database :  (28, 28)

# %%
plt.figure(figsize=(10,10))

for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(train_images[i])
    plt.title(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# WTF c'est quoi cette couleur ? Ah ok en fait c'est normal, les pixels sont pas normalisé donc il fait nimp sur les couleurs, on va normaliser

# %% [raw]
# #TEST
# train_images = train_images / 255.0
# test_images = test_images / 255.0
#
# plt.imshow(train_images[i])
# plt.colorbar()
# plt.title(class_names[train_labels[i]])
# plt.show()

# %% [markdown]
# Ben non c'est une idée de merde allons voir sur internet. Bon askip c'est normal c'est la manière de lire les photo qui de matplotlib mais je comprends pas bien pourquoi on va move on, on reviendra. Mais c'est important de normaliser les pixels donc je vais commenter cette partie et le faire dans le main

# %% [markdown]
# Etape 3 : Construction du modèle

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)), #La taille est cohérente avec notre database 
    tf.keras.layers.Dense(128, activation='relu'), #dense = C'est quand toutes tes couches intermédiaires sont reliées les unes aux autres, pas très efficace
    #relu : Rectified Linear Unit, c'est un type de fonction d'activation, faudra aller voir plus tard ce que c'est 
    tf.keras.layers.Dense(10)
])

# %% [raw]
# Ici on a un modèle avec 3 colonnes de neurones
# Colonne 1 : Flatten (entrée) 1 image de 28*28 donc 784 neuronnes
# Colonne 2 : Dense 128 neuronnes connectées à toutes les neuronnes de la colonne 1. Avec une fonction d'activation.
# Colonne 3 : 10 "neuronnes" (output) qui correspond au 10 catégories qu'on a définit dans class_names

# %% [markdown]
# Etape 4 : Compilation du modèle

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), # Se renseigner sur ce type de fonction de perte 
              metrics=['accuracy'])

# %% [raw]
# Fonction de perte (loss) : Mesure à quel point la valeur obtenu par le modèle est loin du label qui lui est attribué
# Metrics : Evaluation de la performance du modèle

# %% [markdown]
# Etape 5 : Formation du modèle

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7851 - loss: 0.6242
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8611 - loss: 0.3817
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 867us/step - accuracy: 0.8785 - loss: 0.3348
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8864 - loss: 0.3165
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8939 - loss: 0.2922
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8950 - loss: 0.2831
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9019 - loss: 0.2627
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9078 - loss: 0.2529
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9131 - loss: 0.2375
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9122 - loss: 0.2357

# %% [raw]
# Le epochs permet de faire tourner 10 fois le modèle (pour pondérer et ajuster les biais) car il est de fou influencé par l'ordre des images.
# On voit que l'accurracy a grandement augmenté en le faisant plusieurs fois

# %% [markdown]
# Etape 6 : Création d'un modèle de prédiction facilement interprétable

# %%
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])

# %% [raw]
# On vient de fabriquer un modèle prédictif basé sur le modèle qu'on vient d'entrainer. Ayant une fonction d'activation du type Softmax.
#
# Model : C'est vraiment notre modèle initial avec le réseau de neurones comme on l'a défini. La sortie est un nombre entre -1 et 1 pour chaque classe
# probability_model : est un nouveau modèle basé sur le modele qu'on a entrainé "model". Mais la sortie n'est plus -1 à 1 mais une valeur entre 0 et 1 pour chaque classe. De manière à ce que la valeur en sortie de probability_model puisse s'interpréter comme une probabilité. Exemple : Pour cette photo il y a 0.1 de chance que ca soit catégorie 1 ; 0.8 de chance que ça soit catégorie 2 ; 0.1 de chance que ça soit catégorie 3 ; le reste est à 0 etant donné que la somme doit faire 1.

# %% [markdown]
# Etape 7 : Prédiction à partir des images de tests qu'on avait prévus

# %%
predictions = probability_model.predict(test_images)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
plt.figure(figsize=(17, 15))

i=0
while i<10 : 
    plt.subplot(5,2,i+1)
    if i%2 == 0 : 
        plt.imshow(train_images[i])
        plt.title(class_names[train_labels[i]])
    else : 
        plt.bar(range(0,10), predictions[i-1], color='skyblue', edgecolor='black', width=0.6, align='center', alpha=0.7)
        plt.ylabel('Probabilité')
        plt.xticks(classes)
    i+=1
    
plt.show()
print(class_names)
# Out:
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [raw]
# En vrai c'est pas mal du tout, on a quand même pour ces exemple une catégorie qui domine très largement et qui semble toujours être la bonne. Maintenant voyons ce que ça dit sur l'ensemble des photos

# %%
print('Shape de test_images : ', test_images.shape)
print('Shape de prediction : ', predictions.shape)
# Out:
# Shape de test_images :  (10000, 28, 28)
# Shape de prediction :  (10000, 10)

# %%
cat_predict = [] #Catégorie prédite par le modele probability_model
for i in range (predictions.shape[0]) :
    cat_predict.append(np.argmax(predictions[i,:]))

Correct = 0
for i in range (len(cat_predict)) : 
    if cat_predict[i] == test_labels[i] : 
        Correct +=1

plt.bar(['Correct','Wrong'],[Correct, len(cat_predict)-Correct],color='skyblue', edgecolor='black', width=0.6, align='center')
plt.title('Taux de réussite de catégorisation')
# Out:
# Text(0.5, 1.0, 'Taux de réussite de catégorisation')
